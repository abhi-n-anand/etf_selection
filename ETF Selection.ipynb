# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import yfinance as yf 

# %matplotlib inline

# %%
ETFS_AND_MFS = [
"QQQ",
"QQQM",
"VTI",
"VOO",
"SPY",
"VTSAX",
"SQQQ",
"TQQQ"
]

query_str = " ".join(ETFS_AND_MFS)
query_str
# Out:
# 'QQQ QQQM VTI VOO SPY VTSAX SQQQ TQQQ'

# %%
data = yf.download(query_str, period="1y")
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %%
data
# Out:
# Price        Adj Close                                                \
# Ticker             QQQ        QQQM         SPY       SQQQ       TQQQ
# Date
# 2023-06-15  367.802307  151.187607  436.282135  17.892775  40.994751
# 2023-06-16  365.487732  150.224640  434.796051  18.229490  40.206390
# 2023-06-20  364.964539  150.072510  432.540283  18.304317  40.009300
# 2023-06-21  359.990906  148.094086  430.324036  19.049612  38.405838
# 2023-06-22  364.238373  149.764297  431.877411  18.414310  39.681099
# ...                ...         ...         ...        ...        ...
# 2024-06-10  464.829987  191.279999  535.659973   9.220000  67.830002
# 2024-06-11  468.019989  192.600006  536.950012   9.030000  69.230003
# 2024-06-12  474.149994  195.089996  541.359985   8.680000  71.959999
# 2024-06-13  476.720001  196.179993  542.450012   8.540000  73.110001
# 2024-06-14  479.190002  197.190002  542.780029   8.430000  74.169998
#
# ...
